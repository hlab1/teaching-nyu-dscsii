# %% [markdown]
# ## Brief introduction to R

# %% [markdown]
# ### Interacting with the R Jupyter notebook
#
# There are two types of Cells.
# * "Markdown" cells allow you to write text like this one.
# * The two cells below are "Code" cells. Type R commands into the cell and press shift-enter to compute the result.

# %%
2*3
# Out:
# [1] 6

# %%
10-3
# Out:
# [1] 7

# %% [markdown]
# A cell can be in "edit" mode or "command" mode.
# * Edit mode is indicated by green cell border.  You can type into the cell.
# * Command mode is indicated by a grey border with blue left margin.
#
# You can insert a Cell by using the "Insert" option in the menu.

# %% [markdown]
# ### R variables
#
# A variable has a name and a value. For example, in the cell below we are assigning the value 2\*3 to the variable x. Press shift-enter to evaluate it.  Note that this command does not print the result on the screen (why?).

# %%
x = 2*3

# %% [markdown]
# To view the content of the variable *x*, just type its name and press shift-enter.

# %%
x
# Out:
# [1] 6

# %% [markdown]
# All variables in R are called *objects*. There are multiple types of objects in R, including scalars, vectors, matrices, arrays, data frames, tables, and lists.

# %% [markdown]
# A *vector* is a collection of *elements* of the same type.
# We can use the `c()` function to create a vector with the name *myvector*.

# %%
myvector = c(8,6,9,10,5)

# %% [markdown]
# Type the name of this vector to see its value.

# %%
myvector
# Out:
# [1]  8  6  9 10  5

# %% [markdown]
# We can extract elements in the vector by its *index*. Here we are getting the first (position 1) and the fourth (position 4) element in the vector.

# %%
myvector[1]
# Out:
# [1] 8

# %%
myvector[4]
# Out:
# [1] 10

# %% [markdown]
# A *list* can contain elements of different types, for example, numbers or strings, or even vector. We can use the *list()* function to create a list. Values in the list can have names.

# %%
mylist = list("USA"="Washington DC","Canada"="Ottawa",myvector)

# %% [markdown]
# To see the content of *mylist*, just type its name.

# %%
mylist
# Out:
# $USA
# [1] "Washington DC"
#
# $Canada
# [1] "Ottawa"
#
# [[3]]
# [1]  8  6  9 10  5

# %% [markdown]
# We can get individual elements of the list by the name or the index using *double square brackets*.

# %%
mylist[["Canada"]]
# Out:
# [1] "Ottawa"

# %%
mylist[[3]]
# Out:
# [1]  8  6  9 10  5

# %% [markdown]
# The `attributes` function gets all the names in the list.

# %% [markdown]
# ### R functions
# A *function* in R performs some calculations on input variables called *arguments* that are inside a round bracket. For example the `log10()` function calculates the base 10 log of the number passed in the round bracket.

# %%
log10(100)
# Out:
# [1] 2

# %% [markdown]
# The `mean` function calculates the mean of a vector.

# %%
mean(myvector)
# Out:
# [1] 7.6

# %% [markdown]
# The `length` function gives the number of elements in a vector.

# %%
length(myvector)
# Out:
# [1] 5

# %% [markdown]
# The *table* function takes a vector, finds all the possible unique values in the vector, and calculates the number of times that each value appears in the vector.

# %%
class_majors = c("Psychology","Public Health","Biology","Biology","Computer Science","Biology")
table(class_majors)
# Out:
# class_majors
#          Biology Computer Science       Psychology    Public Health
#                3                1                1                1

# %% [markdown]
# Functions can take multiple arguments. The *log(x,y)* function takes the base *y* log of *x*.

# %%
log(16,2)
# Out:
# [1] 4

# %%
log(27,3)
# Out:
# [1] 3

# %% [markdown]
# ### Getting help on functions
# A lot of functions that come with R or R packages provides *inline help*. This allows you to see how to call the functions and what the functions do.
#
# Usually you can just type ? before the function name.
#
# Try getting help for the `log` function.

# %%
?log

# %% [markdown]
# And for the `mean` function.

# %%
?mean

# %% [markdown]
# ## Single cell Ciona dataset - spatial dynamics

# %% [markdown]
# ### Loading the R packages and the spatial dataset

# %% [markdown]
# Many people have written functions for doing analysis in R. The functions are put in R *packages* and *libraries* that must be installed or loaded so the functions can be used.
#
# We use the `library` function here to load the `Seurat` package that provides many functions to analyze single-cell RNA-seq data, and the `RColorBrewer` package that tells R what colors we would use.  The `source` function loads the convenient functions that we use in this lab.

# %%
library(Seurat)
library(RColorBrewer)
source('../src/functions.R')
# Out:
# Loading required package: ggplot2
#
# Loading required package: cowplot
#
#
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************
#
#
# Warning message:
# "namespace 'sn' is not available and has been replaced
# by .GlobalEnv when processing object ''"
# Warning message:
# "namespace 'sn' is not available and has been replaced
# by .GlobalEnv when processing object ''"

# %% [markdown]
# We can now load the `hpf20` object from the R file *spatial.Robj*, which contains the analyzed information about the transcriptomes of cells collected at hpf20. Then load the *temporal.RObj* file that contains the trajectories of all the cell types.

# %%
load('../data/external/spatial.Robj')
load('../data/external/temporal.Robj')

# %% [markdown]
# After loading, you can call the `ls` function to check what variables are currently in the memory.

# %%
ls()
# Out:
#  [1] "asm.test"           "class_majors"       "col"
#  [4] "fhp.test"           "genePlot.pseudo"    "genePlot.pseudo0"
#  [7] "genes.plot.pseudo"  "genes.plot.pseudo0" "hpf20"
# [10] "mylist"             "myvector"           "ps.asm"
# [13] "ps.fhp"             "ps.shp"             "shp.test"
# [16] "x"

# %% [markdown]
# ## Reading the marker genes

# %% [markdown]
# We have a few text files that specify the differential expression of the marker genes in each cell type. Here we read these files into R and filter to keep the ones that show the strongest differential expression

# %%
heartGene = rownames(subset(read.table("../data/external/panHP_20.markers.txt"), power>0.5 & avg_diff>1))
asmGene = rownames(subset(read.table("../data/external/ASM_20.markers.txt"), power>0.5 & avg_diff>1))
shpSpecific = rownames(subset(read.table("../data/external/SHPspecific_20.markers.txt"),power>0.5&avg_diff>1))
fhpSpecific = rownames(subset(read.table("../data/external/FHPspecific_20.markers.txt"),power>0.5&avg_diff>1))

# %% [markdown]
# **Exercise**: How many genes are in each of the vectors *heartGene*, *asmGene*, *shpSpecific* and *fhpSpecific*?  Try to calculate this in the cell below.

# %% [markdown]
# For the purpose of this lab, we will use up to 15 marker genes for each cell type.  We will also define a *All* vector that holds all the (reduced) marker genes.

# %%
ASM = asmGene[1:15]
Heart = heartGene[1:15]
FHP_Specific = fhpSpecific[1:15]
SHP_Specific = shpSpecific
AllGene = c(heartGene[1:15], fhpSpecific[1:15], shpSpecific,asmGene[1:15])

# %% [markdown]
# ### Getting information from the hpf20 object

# %%
hpf20
# Out:
# An object of class seurat in project allhpf
#  14864 genes across 288 samples.

# %% [markdown]
# The *hpf20* object contains many datasets related to the analysis of hpf20 dataset.  We can get the raw sequencing read counts for each gene in each cell in the *raw.data* variable.

# %%
hpf20@raw.data
# Out:
#                              hpf12_hpf12_p3_10_R1tophat_outcufflinks
# C1ORF158                     0
# LASP/1                       0
# KH2013:KH.C1.100             0
# PDCD6IP                      0
# UBE2M                        0
# KH2013:KH.C1.1002            0
# KH2013:KH.C1.1003_F49F1.1    0
# KATNA1                       0
# PLCH1/2                      0
# KH2013:KH.C1.1006            0
# C11ORF70                     0
# MFAP1                        0
# CCDC50                       0
# KH2013:KH.C1.101_CDIPT       0
# KH2013:KH.C1.1010_ITLN3      0
# RAB35                        0
# CHMP5                        0
# KH2013:KH.C1.1013            0
# KH2013:KH.C1.1014            0
# KH2013:KH.C1.1015            0
# NR6A1                        0
# NRCAM                        0
# KH2013:KH.C1.1018            0
# CABP4/5                      0
# KH2013:KH.C1.102             0
# KH2013:KH.C1.1020_MOXD1      0
# PEX5                         0
# KH2013:KH.C1.1022            0
# TM9SF2                       0
# GRWD1                        0
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0
# KH2013:KH.S970.5             0
# KH2013:KH.S972.1_GSTO1/2     0
# KH2013:KH.S972.2             0
# KH2013:KH.S972.3             0
# C17D12.1                     0
# KH2013:KH.S980.1_BPTF        0
# IQCK                         0
# KH2013:KH.S982.1_NUDCD3      0
# KH2013:KH.S982.2             0
# KH2013:KH.S982.3             0
# GPR37                        0
# DYN1                         0
# KH2013:KH.S985.2_HEPHL1      0
# KH2013:KH.S986.1_VPS13C      0
# PARP9                        0
# ARPC1B                       0
# PSMD6                        0
# NANOS1                       0
# SHANK2/3                     0
# STX18                        0
# KH2013:KH.S991.1             0
# RNF11                        0
# KH2013:KH.S992.1_B4GALT1/2/4 0
# SI:DKEY-26C10.5              0
# TTC4                         0
# MNAT1                        0
# KH2013:KH.S999.3             0
# KH2013:KH.S999.4             0
# KH2013:KH.S999.5             0
#                              hpf12_hpf12_p3_11_R1tophat_outcufflinks
# C1ORF158                     5.148244
# LASP/1                       0.000000
# KH2013:KH.C1.100             0.000000
# PDCD6IP                      3.911399
# UBE2M                        5.154291
# KH2013:KH.C1.1002            0.000000
# KH2013:KH.C1.1003_F49F1.1    0.000000
# KATNA1                       4.396392
# PLCH1/2                      3.124033
# KH2013:KH.C1.1006            0.000000
# C11ORF70                     4.181400
# MFAP1                        6.276542
# CCDC50                       3.406195
# KH2013:KH.C1.101_CDIPT       5.424443
# KH2013:KH.C1.1010_ITLN3      0.000000
# RAB35                        4.757410
# CHMP5                        5.338523
# KH2013:KH.C1.1013            0.000000
# KH2013:KH.C1.1014            0.000000
# KH2013:KH.C1.1015            0.000000
# NR6A1                        4.269448
# NRCAM                        0.000000
# KH2013:KH.C1.1018            0.000000
# CABP4/5                      0.000000
# KH2013:KH.C1.102             0.000000
# KH2013:KH.C1.1020_MOXD1      0.000000
# PEX5                         0.000000
# KH2013:KH.C1.1022            4.384789
# TM9SF2                       5.464158
# GRWD1                        0.000000
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             2.4777981
# KH2013:KH.S970.5             0.0000000
# KH2013:KH.S972.1_GSTO1/2     0.0000000
# KH2013:KH.S972.2             0.0000000
# KH2013:KH.S972.3             0.0000000
# C17D12.1                     6.0396498
# KH2013:KH.S980.1_BPTF        0.0000000
# IQCK                         0.0000000
# KH2013:KH.S982.1_NUDCD3      3.9134360
# KH2013:KH.S982.2             0.0000000
# KH2013:KH.S982.3             0.0000000
# GPR37                        0.0000000
# DYN1                         0.0000000
# KH2013:KH.S985.2_HEPHL1      0.0000000
# KH2013:KH.S986.1_VPS13C      3.1662933
# PARP9                        0.2576346
# ARPC1B                       0.0000000
# PSMD6                        0.0000000
# NANOS1                       0.0000000
# SHANK2/3                     0.0000000
# STX18                        0.0000000
# KH2013:KH.S991.1             0.0000000
# RNF11                        0.0000000
# KH2013:KH.S992.1_B4GALT1/2/4 0.0000000
# SI:DKEY-26C10.5              0.0000000
# TTC4                         0.0000000
# MNAT1                        0.0000000
# KH2013:KH.S999.3             0.0000000
# KH2013:KH.S999.4             1.7937442
# KH2013:KH.S999.5             0.8447732
#                              hpf12_hpf12_p3_12_R1tophat_outcufflinks
# C1ORF158                     0.000000e+00
# LASP/1                       2.967240e+00
# KH2013:KH.C1.100             0.000000e+00
# PDCD6IP                      0.000000e+00
# UBE2M                        3.494375e+00
# KH2013:KH.C1.1002            0.000000e+00
# KH2013:KH.C1.1003_F49F1.1    0.000000e+00
# KATNA1                       3.622360e+00
# PLCH1/2                      0.000000e+00
# KH2013:KH.C1.1006            0.000000e+00
# C11ORF70                     0.000000e+00
# MFAP1                        0.000000e+00
# CCDC50                       1.810817e+00
# KH2013:KH.C1.101_CDIPT       3.579781e+00
# KH2013:KH.C1.1010_ITLN3      0.000000e+00
# RAB35                        2.539916e+00
# CHMP5                        4.428790e+00
# KH2013:KH.C1.1013            0.000000e+00
# KH2013:KH.C1.1014            3.484159e+00
# KH2013:KH.C1.1015            6.997645e-05
# NR6A1                        4.555250e+00
# NRCAM                        0.000000e+00
# KH2013:KH.C1.1018            0.000000e+00
# CABP4/5                      0.000000e+00
# KH2013:KH.C1.102             0.000000e+00
# KH2013:KH.C1.1020_MOXD1      0.000000e+00
# PEX5                         2.414931e+00
# KH2013:KH.C1.1022            0.000000e+00
# TM9SF2                       4.625649e+00
# GRWD1                        5.176827e+00
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0.0000000
# KH2013:KH.S970.5             0.0000000
# KH2013:KH.S972.1_GSTO1/2     0.0000000
# KH2013:KH.S972.2             0.0000000
# KH2013:KH.S972.3             0.0000000
# C17D12.1                     3.9432503
# KH2013:KH.S980.1_BPTF        2.6684566
# IQCK                         0.0000000
# KH2013:KH.S982.1_NUDCD3      0.0000000
# KH2013:KH.S982.2             0.0000000
# KH2013:KH.S982.3             0.0000000
# GPR37                        0.0000000
# DYN1                         0.0000000
# KH2013:KH.S985.2_HEPHL1      0.0000000
# KH2013:KH.S986.1_VPS13C      0.0000000
# PARP9                        0.2618164
# ARPC1B                       5.8448682
# PSMD6                        5.7083122
# NANOS1                       0.0000000
# SHANK2/3                     0.0000000
# STX18                        4.2277268
# KH2013:KH.S991.1             0.4731331
# RNF11                        0.0000000
# KH2013:KH.S992.1_B4GALT1/2/4 0.0000000
# SI:DKEY-26C10.5              0.0000000
# TTC4                         3.6603565
# MNAT1                        3.2883758
# KH2013:KH.S999.3             0.0000000
# KH2013:KH.S999.4             3.2905526
# KH2013:KH.S999.5             0.0000000
#                              hpf12_hpf12_p3_13_R1tophat_outcufflinks
# C1ORF158                     0.0000000
# LASP/1                       0.3021299
# KH2013:KH.C1.100             0.0000000
# PDCD6IP                      0.0000000
# UBE2M                        0.0000000
# KH2013:KH.C1.1002            0.0000000
# KH2013:KH.C1.1003_F49F1.1    0.0000000
# KATNA1                       0.0000000
# PLCH1/2                      0.0000000
# KH2013:KH.C1.1006            0.0000000
# C11ORF70                     0.0000000
# MFAP1                        0.9352773
# CCDC50                       0.0000000
# KH2013:KH.C1.101_CDIPT       0.0000000
# KH2013:KH.C1.1010_ITLN3      0.0000000
# RAB35                        1.5413603
# CHMP5                        4.4258425
# KH2013:KH.C1.1013            0.0000000
# KH2013:KH.C1.1014            0.0000000
# KH2013:KH.C1.1015            0.0000000
# NR6A1                        0.0000000
# NRCAM                        0.0000000
# KH2013:KH.C1.1018            0.0000000
# CABP4/5                      0.0000000
# KH2013:KH.C1.102             0.0000000
# KH2013:KH.C1.1020_MOXD1      0.0000000
# PEX5                         0.0000000
# KH2013:KH.C1.1022            0.0000000
# TM9SF2                       4.7100436
# GRWD1                        0.0000000
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0.0000000
# KH2013:KH.S970.5             0.0000000
# KH2013:KH.S972.1_GSTO1/2     0.0000000
# KH2013:KH.S972.2             0.0000000
# KH2013:KH.S972.3             0.0000000
# C17D12.1                     0.0000000
# KH2013:KH.S980.1_BPTF        2.1830006
# IQCK                         0.0000000
# KH2013:KH.S982.1_NUDCD3      4.6998620
# KH2013:KH.S982.2             0.0000000
# KH2013:KH.S982.3             0.0000000
# GPR37                        0.0000000
# DYN1                         0.0000000
# KH2013:KH.S985.2_HEPHL1      2.0089051
# KH2013:KH.S986.1_VPS13C      0.0000000
# PARP9                        0.0000000
# ARPC1B                       0.0000000
# PSMD6                        2.5368506
# NANOS1                       0.0000000
# SHANK2/3                     0.0000000
# STX18                        0.9747973
# KH2013:KH.S991.1             0.0000000
# RNF11                        2.9174193
# KH2013:KH.S992.1_B4GALT1/2/4 0.0000000
# SI:DKEY-26C10.5              0.0000000
# TTC4                         0.0000000
# MNAT1                        0.0000000
# KH2013:KH.S999.3             0.0000000
# KH2013:KH.S999.4             0.0000000
# KH2013:KH.S999.5             0.0000000
#                              hpf12_hpf12_p3_14_R1tophat_outcufflinks
# C1ORF158                     0.0000000
# LASP/1                       0.0000000
# KH2013:KH.C1.100             0.0000000
# PDCD6IP                      0.0000000
# UBE2M                        0.0000000
# KH2013:KH.C1.1002            0.0000000
# KH2013:KH.C1.1003_F49F1.1    0.0000000
# KATNA1                       0.0000000
# PLCH1/2                      0.0000000
# KH2013:KH.C1.1006            0.0000000
# C11ORF70                     0.0000000
# MFAP1                        0.0000000
# CCDC50                       0.0000000
# KH2013:KH.C1.101_CDIPT       0.0000000
# KH2013:KH.C1.1010_ITLN3      0.0000000
# RAB35                        1.2402044
# CHMP5                        0.0000000
# KH2013:KH.C1.1013            0.0000000
# KH2013:KH.C1.1014            0.0000000
# KH2013:KH.C1.1015            0.0000000
# NR6A1                        0.0000000
# NRCAM                        0.0000000
# KH2013:KH.C1.1018            0.0000000
# CABP4/5                      0.0000000
# KH2013:KH.C1.102             0.0000000
# KH2013:KH.C1.1020_MOXD1      0.0000000
# PEX5                         0.0000000
# KH2013:KH.C1.1022            0.0000000
# TM9SF2                       0.9236198
# GRWD1                        1.8019655
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0.0000000
# KH2013:KH.S970.5             3.0635124
# KH2013:KH.S972.1_GSTO1/2     0.0000000
# KH2013:KH.S972.2             0.0000000
# KH2013:KH.S972.3             0.0000000
# C17D12.1                     0.0000000
# KH2013:KH.S980.1_BPTF        2.7830525
# IQCK                         4.6507266
# KH2013:KH.S982.1_NUDCD3      0.0000000
# KH2013:KH.S982.2             0.0000000
# KH2013:KH.S982.3             0.0000000
# GPR37                        0.0000000
# DYN1                         0.0000000
# KH2013:KH.S985.2_HEPHL1      0.0000000
# KH2013:KH.S986.1_VPS13C      3.7874502
# PARP9                        0.2513445
# ARPC1B                       5.4973444
# PSMD6                        2.1788479
# NANOS1                       0.0000000
# SHANK2/3                     0.0000000
# STX18                        0.0000000
# KH2013:KH.S991.1             0.0000000
# RNF11                        0.0000000
# KH2013:KH.S992.1_B4GALT1/2/4 4.4685426
# SI:DKEY-26C10.5              1.6420639
# TTC4                         3.9885154
# MNAT1                        0.0000000
# KH2013:KH.S999.3             0.0000000
# KH2013:KH.S999.4             0.0000000
# KH2013:KH.S999.5             0.0000000
#                              hpf12_hpf12_p3_15_R1tophat_outcufflinks
# C1ORF158                     0.000000e+00
# LASP/1                       0.000000e+00
# KH2013:KH.C1.100             0.000000e+00
# PDCD6IP                      0.000000e+00
# UBE2M                        5.286037e+00
# KH2013:KH.C1.1002            0.000000e+00
# KH2013:KH.C1.1003_F49F1.1    0.000000e+00
# KATNA1                       0.000000e+00
# PLCH1/2                      0.000000e+00
# KH2013:KH.C1.1006            0.000000e+00
# C11ORF70                     4.561060e-06
# MFAP1                        1.267913e+00
# CCDC50                       4.635292e+00
# KH2013:KH.C1.101_CDIPT       5.302016e+00
# KH2013:KH.C1.1010_ITLN3      0.000000e+00
# RAB35                        0.000000e+00
# CHMP5                        0.000000e+00
# KH2013:KH.C1.1013            0.000000e+00
# KH2013:KH.C1.1014            1.111374e+01
# KH2013:KH.C1.1015            0.000000e+00
# NR6A1                        4.043206e+00
# NRCAM                        0.000000e+00
# KH2013:KH.C1.1018            0.000000e+00
# CABP4/5                      0.000000e+00
# KH2013:KH.C1.102             0.000000e+00
# KH2013:KH.C1.1020_MOXD1      0.000000e+00
# PEX5                         0.000000e+00
# KH2013:KH.C1.1022            0.000000e+00
# TM9SF2                       5.585727e+00
# GRWD1                        0.000000e+00
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0.0000000
# KH2013:KH.S970.5             4.2707794
# KH2013:KH.S972.1_GSTO1/2     0.0000000
# KH2013:KH.S972.2             0.0000000
# KH2013:KH.S972.3             0.0000000
# C17D12.1                     5.4577711
# KH2013:KH.S980.1_BPTF        2.0962409
# IQCK                         1.5231281
# KH2013:KH.S982.1_NUDCD3      0.0000000
# KH2013:KH.S982.2             0.0000000
# KH2013:KH.S982.3             0.0000000
# GPR37                        0.7223370
# DYN1                         0.0000000
# KH2013:KH.S985.2_HEPHL1      0.0000000
# KH2013:KH.S986.1_VPS13C      0.0000000
# PARP9                        0.1325447
# ARPC1B                       4.1094072
# PSMD6                        5.0750051
# NANOS1                       0.0000000
# SHANK2/3                     0.0000000
# STX18                        0.0000000
# KH2013:KH.S991.1             0.0000000
# RNF11                        0.0000000
# KH2013:KH.S992.1_B4GALT1/2/4 0.0000000
# SI:DKEY-26C10.5              0.0000000
# TTC4                         4.1069695
# MNAT1                        0.0000000
# KH2013:KH.S999.3             0.0000000
# KH2013:KH.S999.4             4.1135228
# KH2013:KH.S999.5             0.0000000
#                              hpf12_hpf12_p3_16_R1tophat_outcufflinks
# C1ORF158                     0
# LASP/1                       0
# KH2013:KH.C1.100             0
# PDCD6IP                      0
# UBE2M                        0
# KH2013:KH.C1.1002            0
# KH2013:KH.C1.1003_F49F1.1    0
# KATNA1                       0
# PLCH1/2                      0
# KH2013:KH.C1.1006            0
# C11ORF70                     0
# MFAP1                        0
# CCDC50                       0
# KH2013:KH.C1.101_CDIPT       0
# KH2013:KH.C1.1010_ITLN3      0
# RAB35                        0
# CHMP5                        0
# KH2013:KH.C1.1013            0
# KH2013:KH.C1.1014            0
# KH2013:KH.C1.1015            0
# NR6A1                        0
# NRCAM                        0
# KH2013:KH.C1.1018            0
# CABP4/5                      0
# KH2013:KH.C1.102             0
# KH2013:KH.C1.1020_MOXD1      0
# PEX5                         0
# KH2013:KH.C1.1022            0
# TM9SF2                       0
# GRWD1                        0
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0
# KH2013:KH.S970.5             0
# KH2013:KH.S972.1_GSTO1/2     0
# KH2013:KH.S972.2             0
# KH2013:KH.S972.3             0
# C17D12.1                     0
# KH2013:KH.S980.1_BPTF        0
# IQCK                         0
# KH2013:KH.S982.1_NUDCD3      0
# KH2013:KH.S982.2             0
# KH2013:KH.S982.3             0
# GPR37                        0
# DYN1                         0
# KH2013:KH.S985.2_HEPHL1      0
# KH2013:KH.S986.1_VPS13C      0
# PARP9                        0
# ARPC1B                       0
# PSMD6                        0
# NANOS1                       0
# SHANK2/3                     0
# STX18                        0
# KH2013:KH.S991.1             0
# RNF11                        0
# KH2013:KH.S992.1_B4GALT1/2/4 0
# SI:DKEY-26C10.5              0
# TTC4                         0
# MNAT1                        0
# KH2013:KH.S999.3             0
# KH2013:KH.S999.4             0
# KH2013:KH.S999.5             0
#                              hpf12_hpf12_p3_17_R1tophat_outcufflinks
# C1ORF158                     0.000000e+00
# LASP/1                       0.000000e+00
# KH2013:KH.C1.100             0.000000e+00
# PDCD6IP                      3.205170e+00
# UBE2M                        0.000000e+00
# KH2013:KH.C1.1002            0.000000e+00
# KH2013:KH.C1.1003_F49F1.1    0.000000e+00
# KATNA1                       0.000000e+00
# PLCH1/2                      0.000000e+00
# KH2013:KH.C1.1006            0.000000e+00
# C11ORF70                     6.131312e-05
# MFAP1                        2.567354e+00
# CCDC50                       0.000000e+00
# KH2013:KH.C1.101_CDIPT       4.272309e+00
# KH2013:KH.C1.1010_ITLN3      5.243125e-01
# RAB35                        0.000000e+00
# CHMP5                        0.000000e+00
# KH2013:KH.C1.1013            0.000000e+00
# KH2013:KH.C1.1014            0.000000e+00
# KH2013:KH.C1.1015            0.000000e+00
# NR6A1                        0.000000e+00
# NRCAM                        0.000000e+00
# KH2013:KH.C1.1018            0.000000e+00
# CABP4/5                      0.000000e+00
# KH2013:KH.C1.102             0.000000e+00
# KH2013:KH.C1.1020_MOXD1      0.000000e+00
# PEX5                         0.000000e+00
# KH2013:KH.C1.1022            3.520286e+00
# TM9SF2                       5.202770e+00
# GRWD1                        4.892002e+00
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             1.753215e-05
# KH2013:KH.S970.5             0.000000e+00
# KH2013:KH.S972.1_GSTO1/2     0.000000e+00
# KH2013:KH.S972.2             0.000000e+00
# KH2013:KH.S972.3             0.000000e+00
# C17D12.1                     0.000000e+00
# KH2013:KH.S980.1_BPTF        0.000000e+00
# IQCK                         0.000000e+00
# KH2013:KH.S982.1_NUDCD3      0.000000e+00
# KH2013:KH.S982.2             0.000000e+00
# KH2013:KH.S982.3             0.000000e+00
# GPR37                        0.000000e+00
# DYN1                         0.000000e+00
# KH2013:KH.S985.2_HEPHL1      0.000000e+00
# KH2013:KH.S986.1_VPS13C      0.000000e+00
# PARP9                        3.205983e-01
# ARPC1B                       4.208921e+00
# PSMD6                        4.342170e+00
# NANOS1                       0.000000e+00
# SHANK2/3                     1.167174e+00
# STX18                        0.000000e+00
# KH2013:KH.S991.1             0.000000e+00
# RNF11                        0.000000e+00
# KH2013:KH.S992.1_B4GALT1/2/4 0.000000e+00
# SI:DKEY-26C10.5              0.000000e+00
# TTC4                         0.000000e+00
# MNAT1                        0.000000e+00
# KH2013:KH.S999.3             0.000000e+00
# KH2013:KH.S999.4             0.000000e+00
# KH2013:KH.S999.5             0.000000e+00
#                              hpf12_hpf12_p3_18_R1tophat_outcufflinks
# C1ORF158                     0.000000e+00
# LASP/1                       3.939461e+00
# KH2013:KH.C1.100             0.000000e+00
# PDCD6IP                      3.007374e+00
# UBE2M                        3.666135e+00
# KH2013:KH.C1.1002            0.000000e+00
# KH2013:KH.C1.1003_F49F1.1    0.000000e+00
# KATNA1                       0.000000e+00
# PLCH1/2                      2.617819e+00
# KH2013:KH.C1.1006            0.000000e+00
# C11ORF70                     1.107394e-05
# MFAP1                        5.190816e+00
# CCDC50                       3.245132e+00
# KH2013:KH.C1.101_CDIPT       3.901948e+00
# KH2013:KH.C1.1010_ITLN3      0.000000e+00
# RAB35                        3.987565e+00
# CHMP5                        4.096326e+00
# KH2013:KH.C1.1013            0.000000e+00
# KH2013:KH.C1.1014            0.000000e+00
# KH2013:KH.C1.1015            0.000000e+00
# NR6A1                        3.863878e+00
# NRCAM                        1.795029e+00
# KH2013:KH.C1.1018            0.000000e+00
# CABP4/5                      0.000000e+00
# KH2013:KH.C1.102             0.000000e+00
# KH2013:KH.C1.1020_MOXD1      0.000000e+00
# PEX5                         0.000000e+00
# KH2013:KH.C1.1022            0.000000e+00
# TM9SF2                       4.920674e+00
# GRWD1                        5.211108e+00
# <U+22EE>                       <U+22EE>
# KH2013:KH.S970.4             0.000000e+00
# KH2013:KH.S970.5             2.922279e+00
# KH2013:KH.S972.1_GSTO1/2     0.000000e+00
# KH2013:KH.S972.2             0.000000e+00
# KH2013:KH.S972.3             0.000000e+00
# C17D12.1                     0.000000e+00
# KH2013:KH.S980.1_BPTF        3.706862e+00
# IQCK                         1.607319e-06
# KH2013:KH.S982.1_NUDCD3      0.000000e+00
# KH2013:KH.S982.2             0.000000e+00
# KH2013:KH.S982.3             0.000000e+00
# GPR37                        0.000000e+00
# DYN1                         0.000000e+00
# KH2013:KH.S985.2_HEPHL1      0.000000e+00
# KH2013:KH.S986.1_VPS13C      0.000000e+00
# PARP9                        1.322013e-01
# ARPC1B                       5.391630e+00
# PSMD6                        5.227594e+00
# NANOS1                       0.000000e+00
# SHANK2/3                     0.000000e+00
# STX18                        4.248707e+00
# KH2013:KH.S991.1             0.000000e+00
# RNF11                        3.052873e+00
# KH2013:KH.S992.1_B4GALT1/2/4 0.000000e+00
# SI:DKEY-26C10.5              0.000000e+00
# TTC4                         5.213043e+00
# MNAT1                        3.395464e+00
# KH2013:KH.S999.3             0.000000e+00
# KH2013:KH.S999.4             0.000000e+00
# KH2013:KH.S999.5             0.000000e+00
#                              hpf12_hpf12_p3_19_R1tophat_outcufflinks <U+22EF>
# C1ORF158                     0.000000                                <U+22EF>
# LASP/1                       3.649348                                <U+22EF>
# KH2013:KH.C1.100             0.000000                                <U+22EF>
# PDCD6IP                      2.843804                                <U+22EF>
# UBE2M                        3.237124                                <U+22EF>
# KH2013:KH.C1.1002            0.000000                                <U+22EF>
# KH2013:KH.C1.1003_F49F1.1    0.000000                                <U+22EF>
# KATNA1                       0.000000                                <U+22EF>
# PLCH1/2                      0.000000                                <U+22EF>
# KH2013:KH.C1.1006            0.000000                                <U+22EF>
# C11ORF70                     0.000000                                <U+22EF>
# MFAP1                        4.490611                                <U+22EF>
# CCDC50                       0.000000                                <U+22EF>
# KH2013:KH.C1.101_CDIPT       0.000000                                <U+22EF>
# KH2013:KH.C1.1010_ITLN3      0.000000                                <U+22EF>
# RAB35                        3.729321                                <U+22EF>
# CHMP5                        6.045716                                <U+22EF>
# KH2013:KH.C1.1013            3.797855                                <U+22EF>
# KH2013:KH.C1.1014            0.000000                                <U+22EF>
# KH2013:KH.C1.1015            0.000000                                <U+22EF>
# NR6A1                        3.711616                                <U+22EF>
# NRCAM                        3.009541                                <U+22EF>
# KH2013:KH.C1.1018            0.000000                                <U+22EF>
# CABP4/5                      0.000000                                <U+22EF>
# KH2013:KH.C1.102             0.000000                                <U+22EF>
# KH2013:KH.C1.1020_MOXD1      0.000000                                <U+22EF>
# PEX5                         0.000000                                <U+22EF>
# KH2013:KH.C1.1022            3.839001                                <U+22EF>
# TM9SF2                       4.048091                                <U+22EF>
# GRWD1                        5.028436                                <U+22EF>
# <U+22EE>                       <U+22EE>                                <U+22F1>
# KH2013:KH.S970.4             0.000000                                <U+22EF>
# KH2013:KH.S970.5             3.333204                                <U+22EF>
# KH2013:KH.S972.1_GSTO1/2     0.000000                                <U+22EF>
# KH2013:KH.S972.2             0.000000                                <U+22EF>
# KH2013:KH.S972.3             0.000000                                <U+22EF>
# C17D12.1                     0.000000                                <U+22EF>
# KH2013:KH.S980.1_BPTF        1.067930                                <U+22EF>
# IQCK                         1.647306                                <U+22EF>
# KH2013:KH.S982.1_NUDCD3      0.000000                                <U+22EF>
# KH2013:KH.S982.2             0.000000                                <U+22EF>
# KH2013:KH.S982.3             0.000000                                <U+22EF>
# GPR37                        0.000000                                <U+22EF>
# DYN1                         0.000000                                <U+22EF>
# KH2013:KH.S985.2_HEPHL1      0.000000                                <U+22EF>
# KH2013:KH.S986.1_VPS13C      0.000000                                <U+22EF>
# PARP9                        0.000000                                <U+22EF>
# ARPC1B                       4.376206                                <U+22EF>
# PSMD6                        5.620383                                <U+22EF>
# NANOS1                       0.000000                                <U+22EF>
# SHANK2/3                     0.000000                                <U+22EF>
# STX18                        1.062132                                <U+22EF>
# KH2013:KH.S991.1             0.000000                                <U+22EF>
# RNF11                        0.000000                                <U+22EF>
# KH2013:KH.S992.1_B4GALT1/2/4 0.000000                                <U+22EF>
# SI:DKEY-26C10.5              3.251115                                <U+22EF>
# TTC4                         4.732719                                <U+22EF>
# MNAT1                        0.000000                                <U+22EF>
# KH2013:KH.S999.3             0.000000                                <U+22EF>
# KH2013:KH.S999.4             0.000000                                <U+22EF>
# KH2013:KH.S999.5             0.000000                                <U+22EF>
#                              hpf20_wei.20.v.89tophat hpf20_wei.20.v.8tophat
# C1ORF158                     0                       0.000000
# LASP/1                       0                       0.000000
# KH2013:KH.C1.100             0                       0.000000
# PDCD6IP                      0                       4.063306
# UBE2M                        0                       4.810142
# KH2013:KH.C1.1002            0                       0.000000
# KH2013:KH.C1.1003_F49F1.1    0                       0.000000
# KATNA1                       0                       0.000000
# PLCH1/2                      0                       4.221026
# KH2013:KH.C1.1006            0                       0.000000
# C11ORF70                     0                       0.000000
# MFAP1                        0                       3.174890
# CCDC50                       0                       1.414972
# KH2013:KH.C1.101_CDIPT       0                       4.509789
# KH2013:KH.C1.1010_ITLN3      0                       1.378968
# RAB35                        0                       0.000000
# CHMP5                        0                       0.000000
# KH2013:KH.C1.1013            0                       0.000000
# KH2013:KH.C1.1014            0                       0.000000
# KH2013:KH.C1.1015            0                       0.000000
# NR6A1                        0                       5.127648
# NRCAM                        0                       0.000000
# KH2013:KH.C1.1018            0                       0.000000
# CABP4/5                      0                       0.000000
# KH2013:KH.C1.102             0                       0.000000
# KH2013:KH.C1.1020_MOXD1      0                       0.000000
# PEX5                         0                       0.000000
# KH2013:KH.C1.1022            0                       0.000000
# TM9SF2                       0                       4.414941
# GRWD1                        0                       6.118698
# <U+22EE>                       <U+22EE>                <U+22EE>
# KH2013:KH.S970.4             0                       0.00000000
# KH2013:KH.S970.5             0                       3.76680299
# KH2013:KH.S972.1_GSTO1/2     0                       0.00000000
# KH2013:KH.S972.2             0                       0.00000000
# KH2013:KH.S972.3             0                       0.00000000
# C17D12.1                     0                       3.53497041
# KH2013:KH.S980.1_BPTF        0                       3.08603448
# IQCK                         0                       3.11672349
# KH2013:KH.S982.1_NUDCD3      0                       3.52317310
# KH2013:KH.S982.2             0                       0.00000000
# KH2013:KH.S982.3             0                       0.00000000
# GPR37                        0                       0.00000000
# DYN1                         0                       0.00000000
# KH2013:KH.S985.2_HEPHL1      0                       0.00000000
# KH2013:KH.S986.1_VPS13C      0                       0.00000000
# PARP9                        0                       0.03336688
# ARPC1B                       0                       5.80746959
# PSMD6                        0                       5.02631834
# NANOS1                       0                       0.00000000
# SHANK2/3                     0                       0.00000000
# STX18                        0                       4.00816012
# KH2013:KH.S991.1             0                       0.00000000
# RNF11                        0                       0.00000000
# KH2013:KH.S992.1_B4GALT1/2/4 0                       0.00000000
# SI:DKEY-26C10.5              0                       0.00000000
# TTC4                         0                       0.00000000
# MNAT1                        0                       0.00000000
# KH2013:KH.S999.3             0                       0.00000000
# KH2013:KH.S999.4             0                       0.00000000
# ...
# KH2013:KH.S982.1_NUDCD3      0.000000                0
# KH2013:KH.S982.2             0.000000                0
# KH2013:KH.S982.3             0.000000                0
# GPR37                        0.000000                0
# DYN1                         0.000000                0
# KH2013:KH.S985.2_HEPHL1      0.000000                0
# KH2013:KH.S986.1_VPS13C      0.000000                0
# PARP9                        0.000000                0
# ARPC1B                       0.000000                0
# PSMD6                        5.454286                0
# NANOS1                       0.000000                0
# SHANK2/3                     0.000000                0
# STX18                        0.000000                0
# KH2013:KH.S991.1             0.000000                0
# RNF11                        0.000000                0
# KH2013:KH.S992.1_B4GALT1/2/4 0.000000                0
# SI:DKEY-26C10.5              0.000000                0
# TTC4                         0.000000                0
# MNAT1                        0.000000                0
# KH2013:KH.S999.3             0.000000                0
# KH2013:KH.S999.4             0.000000                0
# KH2013:KH.S999.5             0.000000                0
#                              hpf20_wei.20.v.92tophat hpf20_wei.20.v.93tophat
# C1ORF158                     0                       0.000000
# LASP/1                       0                       0.000000
# KH2013:KH.C1.100             0                       0.000000
# PDCD6IP                      0                       0.000000
# UBE2M                        0                       0.000000
# KH2013:KH.C1.1002            0                       0.000000
# KH2013:KH.C1.1003_F49F1.1    0                       0.000000
# KATNA1                       0                       0.000000
# PLCH1/2                      0                       0.000000
# KH2013:KH.C1.1006            0                       0.000000
# C11ORF70                     0                       0.000000
# MFAP1                        0                       0.000000
# CCDC50                       0                       5.451176
# KH2013:KH.C1.101_CDIPT       0                       0.000000
# KH2013:KH.C1.1010_ITLN3      0                       0.000000
# RAB35                        0                       6.419012
# CHMP5                        0                       0.000000
# KH2013:KH.C1.1013            0                       0.000000
# KH2013:KH.C1.1014            0                       0.000000
# KH2013:KH.C1.1015            0                       0.000000
# NR6A1                        0                       1.063517
# NRCAM                        0                       0.000000
# KH2013:KH.C1.1018            0                       0.000000
# CABP4/5                      0                       0.000000
# KH2013:KH.C1.102             0                       0.000000
# KH2013:KH.C1.1020_MOXD1      0                       0.000000
# PEX5                         0                       0.000000
# KH2013:KH.C1.1022            0                       0.000000
# TM9SF2                       0                       6.915138
# GRWD1                        0                       0.000000
# <U+22EE>                       <U+22EE>                <U+22EE>
# KH2013:KH.S970.4             0                       0
# KH2013:KH.S970.5             0                       0
# KH2013:KH.S972.1_GSTO1/2     0                       0
# KH2013:KH.S972.2             0                       0
# KH2013:KH.S972.3             0                       0
# C17D12.1                     0                       0
# KH2013:KH.S980.1_BPTF        0                       0
# IQCK                         0                       0
# KH2013:KH.S982.1_NUDCD3      0                       0
# KH2013:KH.S982.2             0                       0
# KH2013:KH.S982.3             0                       0
# GPR37                        0                       0
# DYN1                         0                       0
# KH2013:KH.S985.2_HEPHL1      0                       0
# KH2013:KH.S986.1_VPS13C      0                       0
# PARP9                        0                       0
# ARPC1B                       0                       0
# PSMD6                        0                       0
# NANOS1                       0                       0
# SHANK2/3                     0                       0
# STX18                        0                       0
# KH2013:KH.S991.1             0                       0
# RNF11                        0                       0
# KH2013:KH.S992.1_B4GALT1/2/4 0                       0
# SI:DKEY-26C10.5              0                       0
# TTC4                         0                       0
# MNAT1                        0                       0
# KH2013:KH.S999.3             0                       0
# KH2013:KH.S999.4             0                       0
# KH2013:KH.S999.5             0                       0
#                              hpf20_wei.20.v.94tophat hpf20_wei.20.v.95tophat
# C1ORF158                     0.000000000             0
# LASP/1                       0.000000000             0
# KH2013:KH.C1.100             0.000000000             0
# PDCD6IP                      2.691215964             0
# UBE2M                        0.000000000             0
# KH2013:KH.C1.1002            0.000000000             0
# KH2013:KH.C1.1003_F49F1.1    0.000000000             0
# KATNA1                       0.000000000             0
# PLCH1/2                      0.000000000             0
# KH2013:KH.C1.1006            0.000000000             0
# C11ORF70                     0.000154941             0
# MFAP1                        4.686869981             0
# CCDC50                       0.000000000             0
# KH2013:KH.C1.101_CDIPT       0.000000000             0
# KH2013:KH.C1.1010_ITLN3      0.000000000             0
# RAB35                        4.387660733             0
# CHMP5                        0.000000000             0
# KH2013:KH.C1.1013            0.000000000             0
# KH2013:KH.C1.1014            0.000000000             0
# KH2013:KH.C1.1015            0.000000000             0
# NR6A1                        5.878189460             0
# NRCAM                        0.000000000             0
# KH2013:KH.C1.1018            0.000000000             0
# CABP4/5                      0.000000000             0
# KH2013:KH.C1.102             0.000000000             0
# KH2013:KH.C1.1020_MOXD1      0.000000000             0
# PEX5                         0.000000000             0
# KH2013:KH.C1.1022            0.000000000             0
# TM9SF2                       4.546619038             0
# GRWD1                        0.000000000             0
# <U+22EE>                       <U+22EE>                <U+22EE>
# KH2013:KH.S970.4             1.7646126392            0
# KH2013:KH.S970.5             4.6607089556            0
# KH2013:KH.S972.1_GSTO1/2     0.0000000000            0
# KH2013:KH.S972.2             0.0000000000            0
# KH2013:KH.S972.3             0.0000000000            0
# C17D12.1                     0.0000000000            0
# KH2013:KH.S980.1_BPTF        3.1957259217            0
# IQCK                         0.0001946701            0
# KH2013:KH.S982.1_NUDCD3      0.0000000000            0
# KH2013:KH.S982.2             0.0000000000            0
# KH2013:KH.S982.3             0.0000000000            0
# GPR37                        0.0000000000            0
# DYN1                         0.0000000000            0
# KH2013:KH.S985.2_HEPHL1      0.0000000000            0
# KH2013:KH.S986.1_VPS13C      0.0000000000            0
# PARP9                        3.1058594108            0
# ARPC1B                       3.7963158137            0
# PSMD6                        4.7083312847            0
# NANOS1                       0.0000000000            0
# SHANK2/3                     0.0000000000            0
# STX18                        0.0000000000            0
# KH2013:KH.S991.1             0.0000000000            0
# RNF11                        0.0000000000            0
# KH2013:KH.S992.1_B4GALT1/2/4 0.0000000000            0
# SI:DKEY-26C10.5              0.0000000000            0
# TTC4                         5.7290050281            0
# MNAT1                        5.6403952905            0
# KH2013:KH.S999.3             0.0000000000            0
# KH2013:KH.S999.4             0.0000000000            0
# KH2013:KH.S999.5             0.0000000000            0
#                              hpf20_wei.20.v.96tophat hpf20_wei.20.v.9tophat
# C1ORF158                     0.000000                0
# LASP/1                       0.000000                0
# KH2013:KH.C1.100             0.000000                0
# PDCD6IP                      0.000000                0
# UBE2M                        0.000000                0
# KH2013:KH.C1.1002            0.000000                0
# KH2013:KH.C1.1003_F49F1.1    0.000000                0
# KATNA1                       0.000000                0
# PLCH1/2                      0.000000                0
# KH2013:KH.C1.1006            0.000000                0
# C11ORF70                     0.000000                0
# MFAP1                        0.000000                0
# CCDC50                       0.000000                0
# KH2013:KH.C1.101_CDIPT       0.000000                0
# KH2013:KH.C1.1010_ITLN3      0.000000                0
# RAB35                        0.000000                0
# CHMP5                        5.638700                0
# KH2013:KH.C1.1013            0.000000                0
# KH2013:KH.C1.1014            0.000000                0
# KH2013:KH.C1.1015            0.000000                0
# NR6A1                        4.244943                0
# NRCAM                        0.000000                0
# KH2013:KH.C1.1018            0.000000                0
# CABP4/5                      0.000000                0
# KH2013:KH.C1.102             0.000000                0
# KH2013:KH.C1.1020_MOXD1      0.000000                0
# PEX5                         0.000000                0
# KH2013:KH.C1.1022            0.000000                0
# TM9SF2                       0.000000                0
# GRWD1                        0.000000                0
# <U+22EE>                       <U+22EE>                <U+22EE>
# KH2013:KH.S970.4             0                       0
# KH2013:KH.S970.5             0                       0
# KH2013:KH.S972.1_GSTO1/2     0                       0
# KH2013:KH.S972.2             0                       0
# KH2013:KH.S972.3             0                       0
# C17D12.1                     0                       0
# KH2013:KH.S980.1_BPTF        0                       0
# IQCK                         0                       0
# KH2013:KH.S982.1_NUDCD3      0                       0
# KH2013:KH.S982.2             0                       0
# KH2013:KH.S982.3             0                       0
# GPR37                        0                       0
# DYN1                         0                       0
# KH2013:KH.S985.2_HEPHL1      0                       0
# KH2013:KH.S986.1_VPS13C      0                       0
# PARP9                        0                       0
# ARPC1B                       0                       0
# PSMD6                        0                       0
# NANOS1                       0                       0
# SHANK2/3                     0                       0
# STX18                        0                       0
# KH2013:KH.S991.1             0                       0
# RNF11                        0                       0
# KH2013:KH.S992.1_B4GALT1/2/4 0                       0
# SI:DKEY-26C10.5              0                       0
# TTC4                         0                       0
# MNAT1                        0                       0
# KH2013:KH.S999.3             0                       0
# KH2013:KH.S999.4             0                       0
# KH2013:KH.S999.5             0                       0

# %% [markdown]
# ### Plotting: tSNE plots, violin plots and heatmaps

# %% [markdown]
# The *hpf20* object contains information about a pre-computed tSNE plot.  We can use the `TSNEPlot` function to draw it

# %%
TSNEPlot(hpf20)
# Out:
# plot without title

# %% [markdown]
# The `TSNEPlot` function can take many arguments that allow customizing the tSNE plot.

# %%
?TSNEPlot

# %% [markdown]
# We can add the cell identity labels and change the colors of the inferred cell identity.

# %%
TSNEPlot(hpf20,do.label=TRUE,colors.use = c("red","orange","lightblue","blue"),pt.size = 1.5)
# Out:
# plot without title

# %% [markdown]
# Using the `FetchData` function, we can take a look at the identity and the transformed dimsion of each cell.

# %%
FetchData(hpf20,c("ident","tSNE_1","tSNE_2"))
# Out:
#                         ident  tSNE_1       tSNE_2
# hpf20_wei.20.i.10tophat 20ASM1   -3.387013   24.771966
# hpf20_wei.20.i.12tophat 20ASM1   -2.479125   77.422566
# hpf20_wei.20.i.14tophat 20SHP     4.466224  -59.609459
# hpf20_wei.20.i.15tophat 20ASM1  -18.056680   28.579309
# hpf20_wei.20.i.16tophat 20ASM1  -12.320180   44.434205
# hpf20_wei.20.i.17tophat 20SHP    22.415492  -32.663981
# hpf20_wei.20.i.19tophat 20SHP     6.968025  -55.001974
# hpf20_wei.20.i.20tophat 20SHP    12.139052  -50.708285
# hpf20_wei.20.i.22tophat 20SHP    19.704500  -25.608085
# hpf20_wei.20.i.23tophat 20ASM1  -38.839152   29.977458
# hpf20_wei.20.i.25tophat 20SHP    13.558859  -44.660404
# hpf20_wei.20.i.26tophat 20SHP    36.512789  -40.791151
# hpf20_wei.20.i.27tophat 20SHP     9.234237  -67.944173
# hpf20_wei.20.i.28tophat 20SHP    23.659305  -23.406131
# hpf20_wei.20.i.29tophat 20FHP    89.401958  -23.705743
# hpf20_wei.20.i.2tophat  20FHP    83.709018  -45.466550
# hpf20_wei.20.i.30tophat 20ASM1   -9.353023   53.108054
# hpf20_wei.20.i.32tophat 20ASM1  -42.156113   17.792618
# hpf20_wei.20.i.34tophat 20FHP    77.160839  -35.391603
# hpf20_wei.20.i.35tophat 20ASM1   -4.271278   56.398148
# hpf20_wei.20.i.37tophat 20FHP    97.035623  -22.858975
# hpf20_wei.20.i.38tophat 20FHP   117.029312   -1.117789
# hpf20_wei.20.i.39tophat 20ASM1  -42.641499   36.502062
# hpf20_wei.20.i.40tophat 20ASM2 -112.887525   33.961039
# hpf20_wei.20.i.41tophat 20FHP    93.964545   -1.126662
# hpf20_wei.20.i.42tophat 20ASM2 -108.455395   20.432837
# hpf20_wei.20.i.43tophat 20ASM1  -71.133600   26.313972
# hpf20_wei.20.i.44tophat 20ASM1   -3.155533   69.307414
# hpf20_wei.20.i.45tophat 20SHP    18.217736  -61.513116
# hpf20_wei.20.i.46tophat 20ASM1    1.047254   71.658303
# <U+22EE>                  <U+22EE> <U+22EE>     <U+22EE>
# hpf20_wei.20.v.18tophat 20SHP   24.13812413 -28.661382
# hpf20_wei.20.v.22tophat 20SHP   -7.49656876 -45.595210
# hpf20_wei.20.v.26tophat 20ASM1 -32.90212607  52.374589
# hpf20_wei.20.v.27tophat 20SHP   32.57752447 -30.524367
# hpf20_wei.20.v.28tophat 20ASM1 -41.92230748  44.262445
# hpf20_wei.20.v.30tophat 20FHP  100.34293699  -7.132685
# hpf20_wei.20.v.31tophat 20SHP   -1.98326203 -61.626505
# hpf20_wei.20.v.34tophat 20ASM2 -96.75115431  16.497180
# hpf20_wei.20.v.35tophat 20ASM1 -27.73465119  44.324799
# hpf20_wei.20.v.36tophat 20SHP    8.47157329 -44.993874
# hpf20_wei.20.v.38tophat 20SHP   11.08298072 -55.866143
# hpf20_wei.20.v.41tophat 20ASM1 -49.04828787  25.750401
# hpf20_wei.20.v.42tophat 20SHP   19.14260729 -29.089737
# hpf20_wei.20.v.43tophat 20SHP   -0.07472441 -71.082823
# hpf20_wei.20.v.44tophat 20FHP   96.61662896 -12.089948
# hpf20_wei.20.v.46tophat 20ASM2 -87.92675704  10.755880
# hpf20_wei.20.v.50tophat 20ASM1 -14.74172481  23.597078
# hpf20_wei.20.v.52tophat 20ASM1 -64.93213181  28.683212
# hpf20_wei.20.v.56tophat 20ASM2 -91.27366706  19.944618
# hpf20_wei.20.v.59tophat 20SHP   26.98493473 -31.704039
# hpf20_wei.20.v.66tophat 20ASM1  -1.21785684  54.738062
# hpf20_wei.20.v.67tophat 20ASM1 -23.76690922  22.011272
# hpf20_wei.20.v.69tophat 20SHP   14.27729418 -29.543457
# hpf20_wei.20.v.70tophat 20SHP   19.07224183 -21.150438
# hpf20_wei.20.v.78tophat 20ASM1 -74.37226770  13.197521
# hpf20_wei.20.v.84tophat 20ASM1 -85.17166827  22.161143
# hpf20_wei.20.v.85tophat 20ASM1 -39.79391137  41.550128
# hpf20_wei.20.v.87tophat 20SHP   28.73627004 -40.583402
# hpf20_wei.20.v.8tophat  20ASM1 -68.83228343   2.216464
# hpf20_wei.20.v.94tophat 20ASM1  -8.82991249  29.627742

# %% [markdown]
# `FetchData` can also get us the expression levels of EBF genes (ASM marker) in each cell?

# %%
FetchData(hpf20,'EBF1/2/3/4')
# Out:
#                         EBF1/2/3/4
# hpf20_wei.20.i.10tophat 4.886220
# hpf20_wei.20.i.12tophat 4.061220
# hpf20_wei.20.i.14tophat 0.000000
# hpf20_wei.20.i.15tophat 6.384329
# hpf20_wei.20.i.16tophat 4.965415
# hpf20_wei.20.i.17tophat 0.000000
# hpf20_wei.20.i.19tophat 0.000000
# hpf20_wei.20.i.20tophat 2.011066
# hpf20_wei.20.i.22tophat 0.000000
# hpf20_wei.20.i.23tophat 5.930086
# hpf20_wei.20.i.25tophat 0.000000
# hpf20_wei.20.i.26tophat 0.000000
# hpf20_wei.20.i.27tophat 0.000000
# hpf20_wei.20.i.28tophat 5.590823
# hpf20_wei.20.i.29tophat 0.000000
# hpf20_wei.20.i.2tophat  3.894378
# hpf20_wei.20.i.30tophat 4.689741
# hpf20_wei.20.i.32tophat 6.019916
# hpf20_wei.20.i.34tophat 0.000000
# hpf20_wei.20.i.35tophat 3.769164
# hpf20_wei.20.i.37tophat 0.000000
# hpf20_wei.20.i.38tophat 0.000000
# hpf20_wei.20.i.39tophat 5.932752
# hpf20_wei.20.i.40tophat 5.524823
# hpf20_wei.20.i.41tophat 2.606468
# hpf20_wei.20.i.42tophat 6.567319
# hpf20_wei.20.i.43tophat 6.233175
# hpf20_wei.20.i.44tophat 5.206339
# hpf20_wei.20.i.45tophat 1.233114
# hpf20_wei.20.i.46tophat 5.084573
# <U+22EE>                  <U+22EE>
# hpf20_wei.20.v.18tophat 0.0000000
# hpf20_wei.20.v.22tophat 0.0000000
# hpf20_wei.20.v.26tophat 6.0762651
# hpf20_wei.20.v.27tophat 0.0000000
# hpf20_wei.20.v.28tophat 5.1030990
# hpf20_wei.20.v.30tophat 0.5673611
# hpf20_wei.20.v.31tophat 0.0000000
# hpf20_wei.20.v.34tophat 4.9414424
# hpf20_wei.20.v.35tophat 4.1608780
# hpf20_wei.20.v.36tophat 3.9076495
# hpf20_wei.20.v.38tophat 0.0000000
# hpf20_wei.20.v.41tophat 6.6565118
# hpf20_wei.20.v.42tophat 0.9277923
# hpf20_wei.20.v.43tophat 0.0000000
# hpf20_wei.20.v.44tophat 0.0000000
# hpf20_wei.20.v.46tophat 4.0095453
# hpf20_wei.20.v.50tophat 4.8357897
# hpf20_wei.20.v.52tophat 5.0836317
# hpf20_wei.20.v.56tophat 5.9748040
# hpf20_wei.20.v.59tophat 0.0000000
# hpf20_wei.20.v.66tophat 5.4663836
# hpf20_wei.20.v.67tophat 4.8372180
# hpf20_wei.20.v.69tophat 6.7953925
# hpf20_wei.20.v.70tophat 3.5853728
# hpf20_wei.20.v.78tophat 6.3738998
# hpf20_wei.20.v.84tophat 6.4603300
# hpf20_wei.20.v.85tophat 5.5917479
# hpf20_wei.20.v.87tophat 0.0000000
# hpf20_wei.20.v.8tophat  6.0071016
# hpf20_wei.20.v.94tophat 5.5780303

# %% [markdown]
# We can overlay the expression of the EBF genes onto the tSNE plot by the `FeaturePlot` function.  This is presented in Figure 1b.

# %%
FeaturePlot(hpf20,features.plot = 'EBF1/2/3/4', pt.size = 2)
# Out:
# plot without title

# %% [markdown]
# **Exercise**: Draw this for the heart maker gene 'GATA4/5/6'.

# %% [markdown]
# `FeaturePlot` can also take a vector of genes to draw all of them in multiple panels.  Recall the *ASM* variable is a vector of (reduced) ASM makers.

# %%
FeaturePlot(hpf20,features.plot = ASM,pt.size = 1.5)
# Out:
# plot without title

# %% [markdown]
# What do the plots look like if you overlay the heart maker expression?

# %%
FeaturePlot(hpf20,features.plot = Heart,pt.size = 1.5)
# Out:
# plot without title

# %% [markdown]
# Violin plots show the distribution of the markers in each cell type.  We first increase the size of the plot so each panel is visible (default is 7 by 7).

# %%
options(repr.plot.width = 12, repr.plot.height = 10)
VlnPlot(hpf20, ASM)
# Out:
# plot without title

# %% [markdown]
# We can show the expression of all the markers across all the cell types in a heatmap.  Note we use all the marker genes stored in the *AllGene* variable.  This is already very close to the heatmap in Fig. 1c. We just need to change the color mapping and change the row/column orders.

# %%
DoHeatmap(hpf20,genes.use=AllGene, order.by.ident = TRUE,slim.col.label = TRUE, draw.line = TRUE,mar=c(8,8))
# Out:
# Warning message in hmFunction(data.use, Rowv = NA, Colv = NA, trace = "none", col = col.use, :
# "Discrepancy: Rowv is FALSE, while dendrogram is `both'. Omitting row dendogram."
# Warning message in hmFunction(data.use, Rowv = NA, Colv = NA, trace = "none", col = col.use, :
# "Discrepancy: Colv is FALSE, while dendrogram is `column'. Omitting column dendogram."
# Plot with title "Color Key
# and Histogram"

# %% [markdown]
# The code below uses more options in the `DoHeatmap` function, getting pretty close to the one presented in Fig. 1c.

# %%
DoHeatmap(hpf20,genes.use = AllGene,order.by.ident = T,
          slim.col.label = T,draw.line = T,key.title = "Expression Level Scale",
          key.xlab = "", key.ylab = "",
          RowSideColors = c(rep("pink",15),rep("red",15),rep("orange",4),rep("blue",15)), 
          mar=c(8,8),col=col,sepcolor="black",sepwidth = c(1,0.2),
          srtCol=0,cex.col = 1,cexRow=1,keysize=1,density.info=c("none"))
# Out:
# Warning message in hmFunction(data.use, Rowv = NA, Colv = NA, trace = "none", col = col.use, :
# "Discrepancy: Rowv is FALSE, while dendrogram is `both'. Omitting row dendogram."
# Warning message in hmFunction(data.use, Rowv = NA, Colv = NA, trace = "none", col = col.use, :
# "Discrepancy: Colv is FALSE, while dendrogram is `column'. Omitting column dendogram."
# plot without title

# %% [markdown]
# ### Single cell Ciona dataset - temporal dynamics

# %% [markdown]
# The *asm.test*, *shp.test*, and *fhp.test* objects that we loaded previously contain pre-computed trajectories for the ASM, SHP and FHP clusters, respectively.  The *ps.asm*, *ps.shp* and *ps.fhp* objects contain the pre-computed regulatory state transition times for the correspoding trajectories.
#
# Here we plot the expression of the SHP marker 'DACH1/2' along the SHP pseudotime trajectory, mark the activation pseudotime (purple vertical line), and the transition between regulatory states. This reproduceds Fig. 2f middle panel.
#
# We first reset the figure size back to the original 7 by 7.

# %%
options(repr.plot.width = 7, repr.plot.height = 7)
genePlot.pseudo(fhp.test,gene='GATA4/5/6',
                col.use = c("green","pink1","red1","red4"),
                do.spline = T,
                name.x = "FHP Trajectory",
                cex.use = 0.8,cex.lab=1,do.logit = T)
abline(v=ps.fhp,lwd=2,lty=2)
# Out:
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# Plot with title ""

# %% [markdown]
# We can also plot all the FHP marker genes.

# %%
genes.plot.pseudo(fhp.test,genes.use = FHP_Specific, lwd=1.5, name.x = "FHP")
# Out:
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# plot without title

# %% [markdown]
# ## Breakout Room Exercises
#
# 1. Show the expression of FHP marker 'MMP21' and SHP marker 'DACH1/2' the tSNE plot.  Then reproduce the violin plots in Fig. 1d for 'MMP21' and 'DACH1/2'.  What are the pro's and con's of each representation?
#
#
# 2. How is the ASM marker 'EBF1/2/3/4' expressed along the ASM pseudotime trajectory (i.e., reproduce the EBF panel in Fig. 3a)?  Along the FHP trajectory?
#   * The colors use in that figure is `c("green","yellow","lightblue","blue1","blue4")`.
#
#
# 3. Create a heatmap of the ASM trajectory, i.e., using the `DoHeatmap` function with the *asm.test* object and *ASM* gene list, and compare to the heatmap in Fig. 3b.

# %%
options(repr.plot.width = 10, repr.plot.height = 6)
FeaturePlot(hpf20,features.plot = c('MMP21','DACH1/2'),pt.size = 1.5)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 6)
VlnPlot(hpf20, c('MMP21','DACH1/2'))
# Out:
# plot without title

# %%
options(repr.plot.width = 7, repr.plot.height = 7)

genePlot.pseudo(asm.test,gene='EBF1/2/3/4',
                col.use = c("green","yellow","lightblue","blue1","blue4"),
                do.spline = T,name.x = "ASM Trajectory",
                cex.use = 0.8,cex.lab=1,do.logit = T)
abline(v=ps.asm,lwd=2,lty=2)


genePlot.pseudo(fhp.test,gene='EBF1/2/3/4',
                col.use = c("green","pink1","red1","red4"),
                do.spline = T,name.x = "FHP Trajectory",
                cex.use = 0.8,cex.lab=1,do.logit = T)
abline(v=ps.fhp,lwd=2,lty=2)
# Out:
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# Warning message:
# "'fetch.data' is deprecated.
# Use 'FetchData' instead.
# See help("Deprecated") and help("Seurat-deprecated")."
# Plot with title ""
# Plot with title ""

# %%
DoHeatmap(asm.test,genes.use = ASM,
          slim.col.label = TRUE, draw.line = TRUE,mar=c(8,8))
# Out:
# Warning message in hmFunction(data.use, Rowv = NA, Colv = NA, trace = "none", col = col.use, :
# "Discrepancy: Rowv is FALSE, while dendrogram is `both'. Omitting row dendogram."
# Warning message in hmFunction(data.use, Rowv = NA, Colv = NA, trace = "none", col = col.use, :
# "Discrepancy: Colv is FALSE, while dendrogram is `column'. Omitting column dendogram."
# Plot with title "Color Key
# and Histogram"
